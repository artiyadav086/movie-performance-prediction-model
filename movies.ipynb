# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\ASUS\Downloads\Movie_collection_train.csv', header= 0)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000           20.1264               59.62               0.462
# 1       43200           20.5462               69.14               0.531
# 2       69400           20.5458               69.14               0.531
# 3       66800           20.6474               59.36               0.542
# 4       72400           21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
df.shape
# Out:
# (400, 19)

# %%
df.describe()
# Out:
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000         55.017180           73.832700
# std     18308.499136        119.755634           13.023426
# min     10000.000000         20.126400           55.920000
# 25%     37800.000000         21.321950           63.250000
# 50%     45000.000000         23.214700           69.030000
# 75%     56500.000000         34.638300           82.840000
# max    100000.000000       1799.524000          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          400.000000    400.000000    400.000000          400.000000
# mean             0.469881  35197.771537    137.581750            7.810275
# std              0.113920   4075.766926     28.990673            1.088694
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %%
sns.jointplot(x= 'Marketin_expense', y= 'Collection', data=df)

# %%
sns.jointplot(x= 'Twitter_hastags', y= 'Collection', data=df)

# %%
sns.jointplot(x= 'Avg_age_actors', y= 'Collection', data=df)

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000           20.1264               59.62               0.462
# 1       43200           20.5462               69.14               0.531
# 2       69400           20.5458               69.14               0.531
# 3       66800           20.6474               59.36               0.542
# 4       72400           21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
sns.countplot(x=df['Genre'])
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
sns.countplot(x=df['MPAA_film_rating'])
# Out:
# <AxesSubplot:xlabel='MPAA_film_rating', ylabel='count'>

# %%
sns.countplot(x=df['3D_available'])
# Out:
# <AxesSubplot:xlabel='3D_available', ylabel='count'>

# %% [markdown]
# 1. missing values in time_taken
# 2. outliers in Marketin_expense, Twitter_hastags, Avg_age_actors
# 3. MPAA_film_rating has only PG rating

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           400 non-null    int64
#  1   Marketin_expense     400 non-null    float64
#  2   Production_expense   400 non-null    float64
#  3   Multiplex_coverage   400 non-null    float64
#  4   Budget               400 non-null    float64
#  5   Movie_length         400 non-null    float64
#  6   Lead_ Actor_Rating   400 non-null    float64
#  7   Lead_Actress_rating  400 non-null    float64
#  8   Director_rating      400 non-null    float64
#  9   Producer_rating      400 non-null    float64
#  10  Critic_rating        400 non-null    float64
#  11  Trailer_views        400 non-null    int64
#  12  Time_taken           392 non-null    float64
#  13  Twitter_hastags      400 non-null    float64
#  14  Genre                400 non-null    object
# ...

# %%
u = np.percentile(df['Marketin_expense'], 99)
u
# Out:
# 472.15221999999983

# %%
df[(df.Marketin_expense>u)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 378       26200           492.964                91.2               0.329
# 380       20800          1799.524                91.2               0.329
# 386       21000           507.876                91.2               0.300
# 398       10000           787.036                91.2               0.307
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 378  35440.900         169.7               9.240                 9.39
# 380  38707.240         165.4               9.170                 9.43
# 386  25841.860         173.5               9.145                 9.32
# 398  30291.415         173.5               9.215                 9.37
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 378            9.235            9.365           6.96         359760
# 380            9.155            9.410           6.96         417588
# ...

# %%
df.Marketin_expense[(df.Marketin_expense>3*u)] = 3*u
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_868\3938892981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Marketin_expense[(df.Marketin_expense>3*u)] = 3*u

# %%
df[(df.Marketin_expense>u)]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 378       26200         492.96400                91.2               0.329
# 380       20800        1416.45666                91.2               0.329
# 386       21000         507.87600                91.2               0.300
# 398       10000         787.03600                91.2               0.307
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 378  35440.900         169.7               9.240                 9.39
# 380  38707.240         165.4               9.170                 9.43
# 386  25841.860         173.5               9.145                 9.32
# 398  30291.415         173.5               9.215                 9.37
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 378            9.235            9.365           6.96         359760
# 380            9.155            9.410           6.96         417588
# ...

# %%
u = np.percentile(df.Twitter_hastags, [99])[0]
u
# Out:
# 308.0

# %%
df[(df.Twitter_hastags>u)]
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 2       69400           20.5458               69.14               0.531
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 2  39912.675         134.6               7.485                 7.57
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# 2            7.495            7.515           7.44         547051      147.88
#
#    Twitter_hastags   Genre  Avg_age_actors MPAA_film_rating  Num_multiplex  \
# 2           2022.4  Comedy              38               PG            458
#
#   3D_available
# 2           NO

# %%
df.Twitter_hastags[(df.Twitter_hastags>u*3)] = u*3
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_868\2347447382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Twitter_hastags[(df.Twitter_hastags>u*3)] = u*3

# %%
df[(df.Twitter_hastags>u)]
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 2       69400           20.5458               69.14               0.531
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 2  39912.675         134.6               7.485                 7.57
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# 2            7.495            7.515           7.44         547051      147.88
#
#    Twitter_hastags   Genre  Avg_age_actors MPAA_film_rating  Num_multiplex  \
# 2            924.0  Comedy              38               PG            458
#
#   3D_available
# 2           NO

# %%
l = np.percentile(df.Avg_age_actors, [1])[0]
l
# Out:
# 20.0

# %%
df[df.Avg_age_actors<l]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 213       56200           22.8104               76.18               0.511
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 213  35413.125         105.8               7.945                 8.04
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 213             7.91            8.215           7.28         504226
#
#      Time_taken  Twitter_hastags   Genre  Avg_age_actors MPAA_film_rating  \
# 213      151.24          204.496  Comedy               3               PG
#
#      Num_multiplex 3D_available
# 213            441          YES

# %%
df.Avg_age_actors[(df.Avg_age_actors<l*0.3)]=l*0.3
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_868\516172005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Avg_age_actors[(df.Avg_age_actors<l*0.3)]=l*0.3

# %%
df[df.Avg_age_actors<l]
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 213       56200           22.8104               76.18               0.511
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 213  35413.125         105.8               7.945                 8.04
#
#      Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# 213             7.91            8.215           7.28         504226
#
#      Time_taken  Twitter_hastags   Genre  Avg_age_actors MPAA_film_rating  \
# 213      151.24          204.496  Comedy               6               PG
#
#      Num_multiplex 3D_available
# 213            441          YES

# %%
df.describe()
# Out:
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000         54.059512           73.832700
# std     18308.499136        106.576597           13.023426
# min     10000.000000         20.126400           55.920000
# 25%     37800.000000         21.321950           63.250000
# 50%     45000.000000         23.214700           69.030000
# 75%     56500.000000         34.638300           82.840000
# max    100000.000000       1416.456660          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          400.000000    400.000000    400.000000          400.000000
# mean             0.469881  35197.771537    137.581750            7.810275
# std              0.113920   4075.766926     28.990673            1.088694
# min              0.129000  19781.355000     76.400000            3.840000
# ...

# %% [markdown]
# ### Missing Value Treatment

# %%
df.Time_taken.fillna(df.Time_taken.mean(), inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           400 non-null    int64
#  1   Marketin_expense     400 non-null    float64
#  2   Production_expense   400 non-null    float64
#  3   Multiplex_coverage   400 non-null    float64
#  4   Budget               400 non-null    float64
#  5   Movie_length         400 non-null    float64
#  6   Lead_ Actor_Rating   400 non-null    float64
#  7   Lead_Actress_rating  400 non-null    float64
#  8   Director_rating      400 non-null    float64
#  9   Producer_rating      400 non-null    float64
#  10  Critic_rating        400 non-null    float64
#  11  Trailer_views        400 non-null    int64
#  12  Time_taken           400 non-null    float64
#  13  Twitter_hastags      400 non-null    float64
#  14  Genre                400 non-null    object
# ...

# %%
df['Trailer_views']= np.array(df['Trailer_views'], dtype=np.float64)

# %%
sns.jointplot(x='Trailer_views', y= 'Collection', data= df)

# %%
df.Trailer_views= np.exp(df.Trailer_views)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.jointplot(x='Trailer_views', y= 'Collection', data= df)

# %%
df.Trailer_views= np.exp(df.Trailer_views)

# %%
df['expense']=df['Marketin_expense']+df['Production_expense']

# %%
df.describe()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\lib\function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#           Collection  Marketin_expense  Production_expense  \
# count     400.000000        400.000000          400.000000
# mean    48646.500000         54.059512           73.832700
# std     18308.499136        106.576597           13.023426
# min     10000.000000         20.126400           55.920000
# 25%     37800.000000         21.321950           63.250000
# 50%     45000.000000         23.214700           69.030000
# 75%     56500.000000         34.638300           82.840000
# max    100000.000000       1416.456660          106.300000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          400.000000    400.000000    400.000000          400.000000
# mean             0.469881  35197.771537    137.581750            7.810275
# ...

# %%
del df['Marketin_expense']

# %%
del df['Production_expense']

# %%
df.head()
# Out:
#    Collection  Multiplex_coverage     Budget  Movie_length  \
# 0       48000               0.462  36524.125         138.7
# 1       43200               0.531  35668.655         152.4
# 2       69400               0.531  39912.675         134.6
# 3       66800               0.542  38873.890         119.3
# 4       72400               0.542  39701.585         127.7
#
#    Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  Producer_rating  \
# 0               7.825                8.095            7.910            7.995
# 1               7.505                7.650            7.440            7.470
# 2               7.485                7.570            7.495            7.515
# 3               6.895                7.035            6.920            7.020
# 4               6.920                7.070            6.815            7.070
#
#    Critic_rating  Trailer_views  Time_taken  Twitter_hastags     Genre  \
# 0           7.94            inf      109.60          223.840  Thriller
# ...

# %%
df['act_rating'] = (df['Lead_ Actor_Rating']+df['Lead_Actress_rating'])/2

# %%
df['director_produc_rating']= (df['Director_rating']+df['Producer_rating'])/2

# %%
del df['Lead_ Actor_Rating']

# %%
del df['Lead_Actress_rating']

# %%
del df['Director_rating']

# %%
del df['Producer_rating']

# %%
df.describe()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\lib\function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#           Collection  Multiplex_coverage        Budget  Movie_length  \
# count     400.000000          400.000000    400.000000    400.000000
# mean    48646.500000            0.469881  35197.771537    137.581750
# std     18308.499136            0.113920   4075.766926     28.990673
# min     10000.000000            0.129000  19781.355000     76.400000
# 25%     37800.000000            0.419000  32721.727500    111.175000
# 50%     45000.000000            0.494500  34593.762500    142.250000
# 75%     56500.000000            0.558000  37142.118750    165.400000
# max    100000.000000            0.615000  48772.900000    173.500000
#
#        Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# count     400.000000          400.0  400.000000       400.000000
# ...

# %%
del df['MPAA_film_rating']

# %%
df.head(10)
# Out:
#    Collection  Multiplex_coverage     Budget  Movie_length  Critic_rating  \
# 0       48000               0.462  36524.125         138.7           7.94
# 1       43200               0.531  35668.655         152.4           7.44
# 2       69400               0.531  39912.675         134.6           7.44
# 3       66800               0.542  38873.890         119.3           8.26
# 4       72400               0.542  39701.585         127.7           8.26
# 5       57400               0.542  35718.650         132.2           7.26
# 6       45800               0.476  33396.660         140.1           8.96
# 7       44200               0.476  34285.460         169.6           7.96
# 8       33000               0.476  31280.205         173.5           7.96
# 9       37800               0.476  33352.220         159.4           7.96
#
#    Trailer_views  Time_taken  Twitter_hastags     Genre  Avg_age_actors  \
# 0            inf      109.60          223.840  Thriller              23
# ...

# %%
sns.countplot(x=df['Trailer_views'])
# Out:
# <AxesSubplot:xlabel='Trailer_views', ylabel='count'>

# %%
del df['Trailer_views']

# %%
df.head(10)
# Out:
#    Collection  Multiplex_coverage     Budget  Movie_length  Critic_rating  \
# 0       48000               0.462  36524.125         138.7           7.94
# 1       43200               0.531  35668.655         152.4           7.44
# 2       69400               0.531  39912.675         134.6           7.44
# 3       66800               0.542  38873.890         119.3           8.26
# 4       72400               0.542  39701.585         127.7           8.26
# 5       57400               0.542  35718.650         132.2           7.26
# 6       45800               0.476  33396.660         140.1           8.96
# 7       44200               0.476  34285.460         169.6           7.96
# 8       33000               0.476  31280.205         173.5           7.96
# 9       37800               0.476  33352.220         159.4           7.96
#
#    Time_taken  Twitter_hastags     Genre  Avg_age_actors  Num_multiplex  \
# 0      109.60          223.840  Thriller              23            494
# ...

# %%
df= pd.get_dummies(df)

# %%
df.head()
# Out:
#    Collection  Multiplex_coverage     Budget  Movie_length  Critic_rating  \
# 0       48000               0.462  36524.125         138.7           7.94
# 1       43200               0.531  35668.655         152.4           7.44
# 2       69400               0.531  39912.675         134.6           7.44
# 3       66800               0.542  38873.890         119.3           8.26
# 4       72400               0.542  39701.585         127.7           8.26
#
#    Time_taken  Twitter_hastags  Avg_age_actors  Num_multiplex  expense  \
# 0      109.60          223.840              23            494  79.7464
# 1      146.64          243.456              42            462  89.6862
# 2      147.88          924.000              38            458  89.6858
# 3      185.36          225.344              45            472  80.0074
# 4      176.48          225.792              55            395  80.7410
#
#    act_rating  director_produc_rating  Genre_Action  Genre_Comedy  \
# ...

# %%
del df['3D_available_NO']

# %%
del df['Genre_Action']

# %%
df.head()
# Out:
#    Collection  Multiplex_coverage     Budget  Movie_length  Critic_rating  \
# 0       48000               0.462  36524.125         138.7           7.94
# 1       43200               0.531  35668.655         152.4           7.44
# 2       69400               0.531  39912.675         134.6           7.44
# 3       66800               0.542  38873.890         119.3           8.26
# 4       72400               0.542  39701.585         127.7           8.26
#
#    Time_taken  Twitter_hastags  Avg_age_actors  Num_multiplex  expense  \
# 0      109.60          223.840              23            494  79.7464
# 1      146.64          243.456              42            462  89.6862
# 2      147.88          924.000              38            458  89.6858
# 3      185.36          225.344              45            472  80.0074
# 4      176.48          225.792              55            395  80.7410
#
#    act_rating  director_produc_rating  Genre_Comedy  Genre_Drama  \
# ...

# %%
df.corr()
# Out:
#                         Collection  Multiplex_coverage    Budget  \
# Collection                1.000000            0.303971  0.754353
# Multiplex_coverage        0.303971            1.000000  0.314842
# Budget                    0.754353            0.314842  1.000000
# Movie_length             -0.278718           -0.714380 -0.233983
# Critic_rating             0.317850            0.066023  0.237713
# Time_taken                0.140573            0.027185  0.069261
# Twitter_hastags           0.052651            0.016897  0.045096
# Avg_age_actors           -0.004951           -0.078275 -0.043389
# Num_multiplex            -0.272365           -0.914065 -0.290950
# expense                  -0.313783           -0.478920 -0.232526
# act_rating               -0.109875           -0.750461 -0.166481
# director_produc_rating   -0.108881           -0.749922 -0.164282
# Genre_Comedy             -0.036113           -0.028551 -0.051806
# ...

# %%
del df['Num_multiplex']

# %%
df.head()
# Out:
#    Collection  Multiplex_coverage     Budget  Movie_length  Critic_rating  \
# 0       48000               0.462  36524.125         138.7           7.94
# 1       43200               0.531  35668.655         152.4           7.44
# 2       69400               0.531  39912.675         134.6           7.44
# 3       66800               0.542  38873.890         119.3           8.26
# 4       72400               0.542  39701.585         127.7           8.26
#
#    Time_taken  Twitter_hastags  Avg_age_actors  expense  act_rating  \
# 0      109.60          223.840              23  79.7464      7.9600
# 1      146.64          243.456              42  89.6862      7.5775
# 2      147.88          924.000              38  89.6858      7.5275
# 3      185.36          225.344              45  80.0074      6.9650
# 4      176.48          225.792              55  80.7410      6.9950
#
#    director_produc_rating  Genre_Comedy  Genre_Drama  Genre_Thriller  \
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
x= df[['Budget']]

# %%
y= df['Collection']

# %%
lm= LinearRegression()

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm.intercept_, lm.coef_)
# Out:
# -70624.10545910447 [3.388584]

# %%
sns.jointplot(x= df['Budget'], y= df['Collection'], kind='reg')

# %%
import statsmodels.api as sn

# %%
x= sn.add_constant(df['Budget'])

# %%
lm = sn.OLS(df['Collection'], x).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Collection   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     525.5
# Date:                Tue, 16 Aug 2022   Prob (F-statistic):           9.43e-75
# Time:                        17:47:58   Log-Likelihood:                -4324.8
# No. Observations:                 400   AIC:                             8654.
# Df Residuals:                     398   BIC:                             8662.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.062e+04   5237.404    -13.485      0.000   -8.09e+04   -6.03e+04
# ...

# %%
# multi regres

# %%
xm = df.drop('Collection', axis =1)

# %%
ym =df['Collection']

# %%
xm_const= sn.add_constant(xm)

# %%
xm_const.head()
# Out:
#    const  Multiplex_coverage     Budget  Movie_length  Critic_rating  \
# 0    1.0               0.462  36524.125         138.7           7.94
# 1    1.0               0.531  35668.655         152.4           7.44
# 2    1.0               0.531  39912.675         134.6           7.44
# 3    1.0               0.542  38873.890         119.3           8.26
# 4    1.0               0.542  39701.585         127.7           8.26
#
#    Time_taken  Twitter_hastags  Avg_age_actors  expense  act_rating  \
# 0      109.60          223.840              23  79.7464      7.9600
# 1      146.64          243.456              42  89.6862      7.5775
# 2      147.88          924.000              38  89.6858      7.5275
# 3      185.36          225.344              45  80.0074      6.9650
# 4      176.48          225.792              55  80.7410      6.9950
#
#    director_produc_rating  Genre_Comedy  Genre_Drama  Genre_Thriller  \
# ...

# %%
lm_multi= sn.OLS(ym, xm_const).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Collection   R-squared:                       0.654
# Model:                            OLS   Adj. R-squared:                  0.641
# Method:                 Least Squares   F-statistic:                     51.95
# Date:                Tue, 16 Aug 2022   Prob (F-statistic):           1.25e-79
# Time:                        17:48:35   Log-Likelihood:                -4280.9
# No. Observations:                 400   AIC:                             8592.
# Df Residuals:                     385   BIC:                             8652.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
lm3= LinearRegression()

# %%
lm3.fit(xm, ym)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_, lm3.coef_)
# Out:
# -121021.20506054451 [ 1.27384113e+04  2.93305159e+00 -1.19197578e+02  3.36179567e+03
#   5.11196329e+01  1.34227016e+01  6.03752604e+01 -2.24316237e+01
#   4.79188795e+03 -4.29854706e+02  3.98767622e+03  4.93770009e+03
#   3.70978982e+03  2.35666623e+03]
